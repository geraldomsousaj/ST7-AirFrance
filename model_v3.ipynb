# %%
from gurobipy import *
#from passenger import *
import pandas as pd

import matplotlib.pyplot as plt
import itertools
import random

# %% [markdown]
# # Data and Variables

# %% [markdown]
# We need to represent and access info for all passengers: gender (weight), which group they belong to, if they need to transfer quickly, etc. For this purpose we created a the class _Passenger_. We also created the class _Group_ to represent each group (numer of women, men, transit time).

# %%
class Passenger(object):
    id_counter = 0
    def __init__(self, group_index, description, transit_time=0):
        """
            group_index : 
            description : men, women, child, wheelchair, stretcher
            transit_time : optional parameter (inf if there is not transit time)
        """

        self.group_index = group_index
        self.id = Passenger.id_counter
        self.description = description
        self.transit_time = transit_time
        self.weight = self.get_weight()

        Passenger.id_counter += 1

    def get_weight(self):
        if self.description == 'women':
            return 70
        elif self.description == 'men':
            return 85
        elif self.description == 'child':
            return 35
        else: 
            return 100 

    def __str__(self):
        return f"{self.id}: ({self.description}, {self.group_index})" 

    def __repr__(self):
        return str(self)

class Group:

    def __init__(self, id, people_count, class_type, transit_time=0):
        self.id = id
        self.class_type = class_type
        self.transit_time = transit_time

        self.members = []

        for desc in people_count:
            for _ in range(people_count[desc]):
                self.members.append(Passenger(
                        self.id,
                        desc,
                        self.transit_time
                    )) 
        
    def __getitem__(self, arg):
        return self.members[arg]

    def __str__(self):
        return f"G{self.id}: " + str(self.members)

    def __repr__(self):
        return str(self)
    

    def __len__(self):
        return len(self.members)

# %% [markdown]
# class Plane:
#
#     def __init__(self, name, rows, columns, barycenter, corridors = None, emergency_exits=None, transfer_priority=None, business=None):
#         self.name = name
#
#         self.rows = rows
#         self.columns = columns
#         self.X = list(range(-rows/2,rows/2))
#
#         'x_max': preprocess['x_max'],
#         'y_max': preprocess['y_max'],
#         'exit': preprocess['exit'],
#         'hallway': preprocess['hallway'],
#         'barycentre': preprocess['barycentre'],
#         'background': preprocess['background'],
#         'seats': {
#             'real': [],
#             'fictive': [],
#             'business': [],
#             'exit': [],
#             'eco': []
#         }
#
#
#
#
# width = 6
# height = 28+4
# X = [-3, -2, -1, 0, 1, 2, 3]
# Y = list(range(-14-2,0)) + list(range(1,2+14+1))
#
#
# plane = Plane("Plane")

# %% [markdown]
# We then create some functions to import the data from the spreadsheets.

# %%
def read_and_preprocess(file, date):
    df = pd.read_excel(file, date)
    
    df.drop(df.tail(2).index, inplace=True)

    df['TransitTime (min)'] = df['TransitTime'].apply(lambda x: float(str(x).split(':')[0])*60+float(str(x).split(':')[1]))

    df[['Femmes', 'Hommes', 'Enfants', 'WCHR', 'WCHB']] = df[['Femmes', 'Hommes', 'Enfants', 'WCHR', 'WCHB']].fillna(0)

    return df

def get_list_passengers(df):
    list_groups = {}

    for idx, row in df.iterrows():


        people_count = {
            'women': int(row['Femmes']),
            'men': int(row['Hommes']),
            'child': int(row['Enfants']),
            'wheelchair': int(row['WCHR']),
            'stretcher': int(row['WCHB']),
        }

        list_groups[int(idx)] = Group(
            id=int(row["Numéro du groupe"])-1, # -1 temporary fix for ids
            people_count = people_count,
            class_type = row["Classe"],
            transit_time=row['TransitTime (min)']
        )
    
    return list_groups

# %%
# Load Passengers in data

df = read_and_preprocess('DataSeating.xlsx', '21Oct')

groups = get_list_passengers(df)

passengers = list()

for g in groups.keys():
    passengers += groups[g].members

passenger_from_id = {}
for p in passengers:
    passenger_from_id[p.id] = p

# %% [markdown]
# As a final setup we define some problem parameters.

# %%
passengers_count = len(passengers)

width = 6
height = 28+4
X = [-3, -2, -1, 0, 1, 2, 3]
Y = list(range(-14-2,0)) + list(range(1,2+14+1))

total_weight = sum(p.weight for p in passengers)

# %% [markdown]
# # Model Definition

# %%
m = Model("model_v1")

# %% [markdown]
# The main decision variable here is the allocation $A^p_{(i~,~j)}$ : binary variable that says for each passenger with id $p$ if he is located at the seat in coordinates $(i~,~j)$.
#
#
# This is represented in python by the variable allocation[p, i, j].
#
# For instance, if passenger 1 is at the place : (2, 3), then allocation[1,2,3] = 1. Else, it equals 0.

# %%
# Allocation Variables
allocation = m.addVars(passengers_count, width+1, height, vtype=GRB.BINARY, name="Allocation")

# %% [markdown]
# # Constraints

# %% [markdown]
# **At most 1 person per seat:** there can't be more than 1 person in each seat.
#
# $$\sum_{p \in \text{Passengers}} A^p_{(i~,~j)} \leq 1~~\forall (i, j) \in \text{Seats}$$

# %%
# Make sure that there is at most one person per seat
C_limited_seat = m.addConstrs((quicksum([allocation[p.id,i,j] for p in passengers]) <= 1 for i in range(width+1) for j in range(height)))

# %% [markdown]
# **Every passenger is served:** every passenger should be allocated to precisely one seat.
#
# $$\sum_{(i,j) \in \text{Seats}} A^p_{(i~,~j)} == 1~~\forall p \in \text{Passengers}$$

# %%
# Maker sure that everyone is seated and only in one spot
C_serve_all = m.addConstrs((quicksum([allocation[p.id,i,j] for i in range(width+1) for j in range(height) ]) == 1 for p in passengers))

# %% [markdown]
# **Empty Corridor**: there should be no passenger allocated to the corridor (i=3).
# $$A^p_{(i,j)}==0~~\forall (p,i,j) \in \text{Passengers} \times \text{Seats}$$

# %%
# Make sure that the corridor is not considered as a possible seat
C_empty_corridor = m.addConstrs((0 == allocation[p,3,j] for p in range(passengers_count) for j in range(height)))

# %% [markdown]
# **Barycenter Constraint:** the center of mass of the passengers must reside within a limited area. For this purpose the barycenter function is divided into its X and Y coordinate and then each constraint is divided into an inferior limit and a superior limit constraint.
#
# $$ \frac{1}{w_t}\sum_{(p,i,j) \in \text{Passengers} \times \text{Seats}} A^p_{(i,j)} \cdot w(p) \cdot X(i) \leq B_{max}^X$$
#
# $$ \frac{1}{w_t}\sum_{(p,i,j) \in \text{Passengers} \times \text{Seats}} A^p_{(i,j)} \cdot w(p) \cdot X(i) \geq B_{min}^X$$
#
# $$ \frac{1}{w_t}\sum_{(p,i,j) \in \text{Passengers} \times \text{Seats}} A^p_{(i,j)} \cdot w(p) \cdot Y(j) \leq B_{max}^Y$$
#
# $$ \frac{1}{w_t}\sum_{(p,i,j) \in \text{Passengers} \times \text{Seats}} A^p_{(i,j)} \cdot w(p) \cdot Y(j) \geq B_{min}^Y$$
#
#
# Where :
# - $w_t$ is the total weight of all passengers.
# - $w(p)$ is the weight of passenger with id $p$.
# - $X(i)$ is the distance in meters at coordinate i.
# - $Y(j)$ is the distance in meters at coordinate j.
# - $B_{max}^X$ is the upper bound of the barycenter in the X axis.
# - $B_{min}^X$ is the lower bound of the barycenter in the X axis.
# - $B_{max}^Y$ is the upper bound of the barycenter in the Y axis.
# - $B_{min}^Y$ is the lower bound of the barycenter in the Y axis.

# %%
# Center of Mass function
barycenter_X = quicksum([p.weight * allocation[p.id,i,j]*X[i] for p in passengers for i in range(width+1) for j in range(height)])/total_weight
barycenter_Y = quicksum([p.weight * allocation[p.id,i,j]*Y[j] for p in passengers for i in range(width+1) for j in range(height)])/total_weight

# Barycenter limits
bary_lim_X = 1
bary_lim_Y = 2

# Make sure that the center of mass is centralized

C_bary_X_p = m.addConstr(barycenter_X <=  bary_lim_X)
C_bary_X_m = m.addConstr(barycenter_X >= -bary_lim_X)
C_bary_Y_p = m.addConstr(barycenter_Y <=  bary_lim_Y)
C_bary_Y_m = m.addConstr(barycenter_Y >= -bary_lim_Y)

# %% [markdown]
# **Transit Time Constraint**: the people with a transit time inferior to 90 minutes should stay in the front.
#
# $$ A^p_{(i,j)} \leq \epsilon(p) ~~ \forall (p,i,j) \in \text{Passengers in transit} \times \text{Columns} \times \text{Upper rows}$$
#
# Where $\epsilon(p)$ is a new auxiliary variable that we want to minimize.

# %%
epsilon = m.addVars([p.id for p in passengers if p.transit_time < 90], vtype=GRB.BINARY)
m.addConstrs(allocation[p.id,i,j] <= epsilon[p.id] for i in range(width+1) for j in range(height) for p in passengers if p.transit_time < 90 and j > 13);

# %% [markdown]
# **No Child Alone Constraint:**

# %%
def in_grid(i, j):
    return i>=0 and j>=0 and j<height and i <= width

e_allocation = lambda p, i, j: allocation[p,i,j] if in_grid(i,j) else 0


m.addConstrs(
    quicksum([e_allocation(adult.id,i-1,j) + e_allocation(adult.id,i+1,j) for adult in passengers if adult.description != "child"])
    >= allocation[child.id,i,j] for i in range(width+1) for j in range(height) for child in passengers if child.description == "child")
# Out:
# {(0, 0, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 1, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 2, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 3, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 4, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 5, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 6, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 7, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 8, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 9, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 10, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 11, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 12, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 13, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 14, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 15, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 16, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 17, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 18, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 19, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 20, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 21, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 22, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 23, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 24, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 25, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 26, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 27, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 28, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 29, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 30, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 31, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 0, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 1, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 2, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 3, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 4, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 5, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 6, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 7, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 8, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 9, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 10, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 11, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 12, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 13, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 14, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 15, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 16, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 17, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 18, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 19, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 20, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 21, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 22, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 23, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 24, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 25, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 26, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 27, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 28, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 29, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 30, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 31, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 0, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 1, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 2, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 3, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 4, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 5, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 6, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 7, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 8, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 9, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 10, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 11, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 12, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 13, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 14, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 15, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 16, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 17, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 18, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 19, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 20, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 21, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 22, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 23, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 24, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 25, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 26, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 27, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 28, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 29, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 30, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 31, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 0, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 1, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 2, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 3, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 4, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 5, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 6, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 7, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 8, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 9, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 10, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 11, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 12, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 13, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 14, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 15, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 16, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 17, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 18, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 19, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 20, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 21, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 22, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 23, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 24, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 25, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 26, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 27, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 28, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 29, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 30, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 31, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 0, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 1, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 2, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 3, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 4, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 5, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 6, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 7, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 8, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 9, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 10, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 11, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 12, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 13, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 14, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 15, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 16, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 17, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 18, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 19, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 20, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 21, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 22, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 23, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 24, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 25, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 26, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 27, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 28, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 29, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 30, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 31, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 0, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 1, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 2, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 3, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 4, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 5, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 6, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 7, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 8, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 9, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 10, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 11, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 12, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 13, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 14, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 15, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 16, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 17, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 18, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 19, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 20, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 21, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 22, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 23, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 24, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 25, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 26, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 27, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 28, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 29, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 30, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 31, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 0, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 1, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 2, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 3, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 4, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 5, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 6, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 7, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 8, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 9, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 10, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 11, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 12, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 13, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 14, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 15, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 16, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 17, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 18, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 19, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 20, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 21, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 22, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 23, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 24, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 25, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 26, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 27, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 28, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 29, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 30, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>,
#  (6, 31, 33: (child, 20)): <gurobi.Constr *Awaiting Model Update*>}

# %% [markdown]
# # Objective Function

# %% [markdown]
# As a precise calculation of the satisfying function leads to a combinatorial explosion, we decided to instead try to reduce the rectangle formed by the distribution of people from the same group, in this way they try to collapse to the same region of the plane.
#
# For this we will need the following additional variables:
# - $i^G_{max}$: highest $i$ coordinate between members of group $G$.
# - $i^G_{min}$: lowest $i$ coordinate between members of group $G$.
# - $j^G_{max}$: highest $j$ coordinate between members of group $G$.
# - $j^G_{min}$: lowest $j$ coordinate between members of group $G$.
# - $\Delta i^G$: $i^G_{max}-i^G_{min}$
# - $\Delta j^G$: $j^G_{max}-j^G_{min}$
#
# The first 4 variables are set by defining inequality constraints based on the coordinates of the members of a group and the 2 last variables are set by defining equality constraints. Thus, our objective function becomes.
#
# $$ \sum_{G \in \text{Groups}} \Delta i^G + \phi \cdot \Delta j^G + \sum_{p \in G} \epsilon(p) $$
#
# Where $\phi$ is a factor for giving priorities to grouping people in the same rows.

# %%
#i_p = m.addVars(passengers_count, vtype=GRB.INTEGER, lb=0, ub=width, name="i_p")
#j_p = m.addVars(passengers_count, vtype=GRB.INTEGER, lb=0, ub=height, name="j_p")

groups_good = []
for g in groups:
    if len(groups[g])>1:
        groups_good.append(g)


i_g_max = m.addVars(len(groups), vtype=GRB.INTEGER, lb=0, ub=width, name="i_g_max")
i_g_min = m.addVars(len(groups), vtype=GRB.INTEGER, lb=0, ub=width, name="i_g_min")
j_g_max = m.addVars(len(groups), vtype=GRB.INTEGER, lb=0, ub=height, name="j_g_max")
j_g_min = m.addVars(len(groups), vtype=GRB.INTEGER, lb=0, ub=height, name="j_g_min")

#i_g_delta = m.addVars(len(groups), vtype=GRB.INTEGER, lb=1, ub=width, name="i_g_delta")
#j_g_delta = m.addVars(len(groups), vtype=GRB.INTEGER, lb=0, ub=height, name="j_g_delta")

#m.addConstrs((i_p[p] == quicksum([i*allocation[p,i,j] for i in range(width+1) for j in range(height)]) for p in range(passengers_count)))
#m.addConstrs((j_p[p] == quicksum([j*allocation[p,i,j] for i in range(width+1) for j in range(height)]) for p in range(passengers_count)))

for g in range(len(groups)):
    if len(groups[g].members) > 1 :
    
        m.addConstrs(( i_g_max[g] >= quicksum([i*allocation[p.id,i,j] for i in range(width+1) for j in range(height)]) for p in groups[g].members ))
        m.addConstrs(( i_g_min[g] <= quicksum([i*allocation[p.id,i,j] for i in range(width+1) for j in range(height)]) for p in groups[g].members ))

        m.addConstrs(( j_g_max[g] >= quicksum([j*allocation[p.id,i,j] for i in range(width+1) for j in range(height)]) for p in groups[g].members ))
        m.addConstrs(( j_g_min[g] <= quicksum([j*allocation[p.id,i,j] for i in range(width+1) for j in range(height)]) for p in groups[g].members ))
        
        m.addConstr(i_g_max[g] >= i_g_min[g])
        m.addConstr(j_g_max[g] >= j_g_min[g])

        #m.addConstr(i_g_delta[g] == i_g_max[g] - i_g_min[g])
        #m.addConstr(j_g_delta[g] == j_g_max[g] - j_g_min[g])

        m.addConstr((i_g_max[g] - i_g_min[g] + j_g_max[g] - j_g_min[g] >= 1))


m.setObjective( i_g_max.sum() - i_g_min.sum() + 50*j_g_max.sum() - 50*j_g_min.sum() + epsilon.sum()+(width+50*height)*(len(groups)-len(groups_good)), GRB.MINIMIZE)

# %%
j_g_max
# Out:
# {0: <gurobi.Var *Awaiting Model Update*>,
#  1: <gurobi.Var *Awaiting Model Update*>,
#  2: <gurobi.Var *Awaiting Model Update*>,
#  3: <gurobi.Var *Awaiting Model Update*>,
#  4: <gurobi.Var *Awaiting Model Update*>,
#  5: <gurobi.Var *Awaiting Model Update*>,
#  6: <gurobi.Var *Awaiting Model Update*>,
#  7: <gurobi.Var *Awaiting Model Update*>,
#  8: <gurobi.Var *Awaiting Model Update*>,
#  9: <gurobi.Var *Awaiting Model Update*>,
#  10: <gurobi.Var *Awaiting Model Update*>,
#  11: <gurobi.Var *Awaiting Model Update*>,
#  12: <gurobi.Var *Awaiting Model Update*>,
#  13: <gurobi.Var *Awaiting Model Update*>,
#  14: <gurobi.Var *Awaiting Model Update*>,
#  15: <gurobi.Var *Awaiting Model Update*>,
#  16: <gurobi.Var *Awaiting Model Update*>,
#  17: <gurobi.Var *Awaiting Model Update*>,
#  18: <gurobi.Var *Awaiting Model Update*>,
#  19: <gurobi.Var *Awaiting Model Update*>,
#  20: <gurobi.Var *Awaiting Model Update*>,
#  21: <gurobi.Var *Awaiting Model Update*>,
#  22: <gurobi.Var *Awaiting Model Update*>,
#  23: <gurobi.Var *Awaiting Model Update*>,
#  24: <gurobi.Var *Awaiting Model Update*>,
#  25: <gurobi.Var *Awaiting Model Update*>,
#  26: <gurobi.Var *Awaiting Model Update*>,
#  27: <gurobi.Var *Awaiting Model Update*>,
#  28: <gurobi.Var *Awaiting Model Update*>,
#  29: <gurobi.Var *Awaiting Model Update*>,
#  30: <gurobi.Var *Awaiting Model Update*>,
#  31: <gurobi.Var *Awaiting Model Update*>,
#  32: <gurobi.Var *Awaiting Model Update*>,
#  33: <gurobi.Var *Awaiting Model Update*>,
#  34: <gurobi.Var *Awaiting Model Update*>,
#  35: <gurobi.Var *Awaiting Model Update*>,
#  36: <gurobi.Var *Awaiting Model Update*>,
#  37: <gurobi.Var *Awaiting Model Update*>,
#  38: <gurobi.Var *Awaiting Model Update*>,
#  39: <gurobi.Var *Awaiting Model Update*>,
#  40: <gurobi.Var *Awaiting Model Update*>,
#  41: <gurobi.Var *Awaiting Model Update*>,
#  42: <gurobi.Var *Awaiting Model Update*>,
#  43: <gurobi.Var *Awaiting Model Update*>,
#  44: <gurobi.Var *Awaiting Model Update*>,
#  45: <gurobi.Var *Awaiting Model Update*>,
#  46: <gurobi.Var *Awaiting Model Update*>,
#  47: <gurobi.Var *Awaiting Model Update*>,
#  48: <gurobi.Var *Awaiting Model Update*>,
#  49: <gurobi.Var *Awaiting Model Update*>,
#  50: <gurobi.Var *Awaiting Model Update*>,
#  51: <gurobi.Var *Awaiting Model Update*>,
#  52: <gurobi.Var *Awaiting Model Update*>,
#  53: <gurobi.Var *Awaiting Model Update*>,
#  54: <gurobi.Var *Awaiting Model Update*>,
#  55: <gurobi.Var *Awaiting Model Update*>,
#  56: <gurobi.Var *Awaiting Model Update*>,
#  57: <gurobi.Var *Awaiting Model Update*>,
#  58: <gurobi.Var *Awaiting Model Update*>,
#  59: <gurobi.Var *Awaiting Model Update*>,
#  60: <gurobi.Var *Awaiting Model Update*>,
#  61: <gurobi.Var *Awaiting Model Update*>,
#  62: <gurobi.Var *Awaiting Model Update*>,
#  63: <gurobi.Var *Awaiting Model Update*>,
#  64: <gurobi.Var *Awaiting Model Update*>,
#  65: <gurobi.Var *Awaiting Model Update*>,
#  66: <gurobi.Var *Awaiting Model Update*>,
#  67: <gurobi.Var *Awaiting Model Update*>,
#  68: <gurobi.Var *Awaiting Model Update*>,
#  69: <gurobi.Var *Awaiting Model Update*>,
#  70: <gurobi.Var *Awaiting Model Update*>,
#  71: <gurobi.Var *Awaiting Model Update*>,
#  72: <gurobi.Var *Awaiting Model Update*>,
#  73: <gurobi.Var *Awaiting Model Update*>,
#  74: <gurobi.Var *Awaiting Model Update*>,
#  75: <gurobi.Var *Awaiting Model Update*>,
#  76: <gurobi.Var *Awaiting Model Update*>,
#  77: <gurobi.Var *Awaiting Model Update*>,
#  78: <gurobi.Var *Awaiting Model Update*>,
#  79: <gurobi.Var *Awaiting Model Update*>,
#  80: <gurobi.Var *Awaiting Model Update*>,
#  81: <gurobi.Var *Awaiting Model Update*>,
#  82: <gurobi.Var *Awaiting Model Update*>,
#  83: <gurobi.Var *Awaiting Model Update*>,
#  84: <gurobi.Var *Awaiting Model Update*>,
#  85: <gurobi.Var *Awaiting Model Update*>,
#  86: <gurobi.Var *Awaiting Model Update*>,
#  87: <gurobi.Var *Awaiting Model Update*>,
#  88: <gurobi.Var *Awaiting Model Update*>,
#  89: <gurobi.Var *Awaiting Model Update*>,
#  90: <gurobi.Var *Awaiting Model Update*>,
#  91: <gurobi.Var *Awaiting Model Update*>,
#  92: <gurobi.Var *Awaiting Model Update*>,
#  93: <gurobi.Var *Awaiting Model Update*>,
#  94: <gurobi.Var *Awaiting Model Update*>,
#  95: <gurobi.Var *Awaiting Model Update*>,
#  96: <gurobi.Var *Awaiting Model Update*>,
#  97: <gurobi.Var *Awaiting Model Update*>,
#  98: <gurobi.Var *Awaiting Model Update*>,
#  99: <gurobi.Var *Awaiting Model Update*>,
#  100: <gurobi.Var *Awaiting Model Update*>,
#  101: <gurobi.Var *Awaiting Model Update*>,
#  102: <gurobi.Var *Awaiting Model Update*>,
#  103: <gurobi.Var *Awaiting Model Update*>,
#  104: <gurobi.Var *Awaiting Model Update*>,
#  105: <gurobi.Var *Awaiting Model Update*>,
#  106: <gurobi.Var *Awaiting Model Update*>,
#  107: <gurobi.Var *Awaiting Model Update*>,
#  108: <gurobi.Var *Awaiting Model Update*>,
#  109: <gurobi.Var *Awaiting Model Update*>,
#  110: <gurobi.Var *Awaiting Model Update*>}

# %% [markdown]
# **Observation:** unfortunately our objective function couldn't calculate an optimal solution in due time. Thus for this delivery we only considered the $j$ coordinate which is really far away from being a good solution.

# %%
#m.setParam("MIPFocus", 3) 
#m.setParam("Cuts", 2) 
m.setParam('MIPGap', 0.2)
m.update()
m.optimize()
# Out:
# Set parameter MIPGap to value 0.2
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13109 rows, 34588 columns and 339712 nonzeros
# Model fingerprint: 0x79f96b50
# Variable types: 0 continuous, 34588 integer (34144 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 3e+01]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 2e+00]
# Found heuristic solution: objective 18947.000000
# Presolve removed 12089 rows and 393 columns
# Presolve time: 1.15s
# Presolved: 1020 rows, 34195 columns, 251025 nonzeros
# Variable types: 4 continuous, 34191 integer (34050 binary)
# Found heuristic solution: objective 18946.000000
#
# Root relaxation: objective 3.500000e+01, 2509 iterations, 0.46 seconds (0.57 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   35.00000    0  162 18946.0000   35.00000   100%     -    3s
# H    0     0                    3701.0000000   35.00000  99.1%     -    3s
# H    0     0                    3102.0000000   35.00000  98.9%     -    4s
# H    0     0                    2345.0000000   35.00000  98.5%     -    5s
#      0     0   35.00000    0  303 2345.00000   35.00000  98.5%     -    5s
# H    0     0                     393.0000000   35.00000  91.1%     -   12s
# H    0     0                     220.0000000   35.00000  84.1%     -   12s
# H    0     0                     212.0000000   35.00000  83.5%     -   12s
# H    0     0                     162.0000000   35.00000  78.4%     -   12s
#      0     0   35.00000    0  316  162.00000   35.00000  78.4%     -   13s
#      0     0   35.00000    0  124  162.00000   35.00000  78.4%     -   15s
# H    0     0                     161.0000000   35.00000  78.3%     -   15s
#      0     0   35.00000    0  176  161.00000   35.00000  78.3%     -   15s
# H    0     0                     151.0000000   35.00000  76.8%     -   16s
#      0     0   35.00000    0  106  151.00000   35.00000  76.8%     -   18s
# H    0     0                      48.0000000   35.00000  27.1%     -   18s
#      0     0   35.00000    0  225   48.00000   35.00000  27.1%     -   19s
#      0     0   35.00000    0  121   48.00000   35.00000  27.1%     -   21s
#      0     0   35.00000    0  232   48.00000   35.00000  27.1%     -   21s
# H    0     0                      43.0000000   35.00000  18.6%     -   22s
#
# Cutting planes:
#   Cover: 31
#   Implied bound: 5
#   Clique: 22
#   MIR: 48
#   StrongCG: 18
#   GUB cover: 47
#   Zero half: 26
#   RLT: 33
#   Relax-and-lift: 47
#
# Explored 1 nodes (65827 simplex iterations) in 22.51 seconds (18.84 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 43 48 151 ... 3102
#
# Optimal solution found (tolerance 2.00e-01)
# Best objective 4.300000000000e+01, best bound 3.500000000001e+01, gap 18.6047%

# %% [markdown]
# # Verifying Results
# - Green Seats: people travelling alone
# - Orange Seats: people travelling in group, the printed number corresponds to the group id.
# - Asterisk: people with transit time inferior to 90 minutes.
# - Blue Rectangle: limits of the acceptable barycenter.
# - Red Circle: actual barycenter.

# %%
cm_x = round(barycenter_X.getValue(),2)
cm_y = round(barycenter_Y.getValue(),2)

print(f"Center of Mass: {(cm_x, cm_y)}")


fig = plt.figure(figsize=(5,10));
for seat in itertools.product(X,Y):
    if seat[0] != 0:
        plt.plot(seat[0],seat[1],'s', color="gray", markersize=15)

plt.plot([bary_lim_X, bary_lim_X]  , [-bary_lim_Y, bary_lim_Y],   color="cyan")
plt.plot([-bary_lim_X, -bary_lim_X], [-bary_lim_Y, bary_lim_Y],   color="cyan")
plt.plot([-bary_lim_X, bary_lim_X] , [bary_lim_Y, bary_lim_Y],    color="cyan")
plt.plot([-bary_lim_X, bary_lim_X] , [-bary_lim_Y, -bary_lim_Y],   color="cyan")

#for g in range(len(groups)):
    #print(j_g_max[g].x, j_g_min[g].x)

for a in allocation:
    if allocation[a].x == 1:
        label = ""
        if len(groups[passenger_from_id[a[0]].group_index].members) == 1:
            color = "green"
        else:
            color = "orange"
            label = label + str(passengers[a[0]].group_index)
            
        
        #plt.plot(X[a[1]],Y[a[2]], 'o',color=colors[passengers[a[0]].group_index-1])
        plt.plot(X[a[1]], Y[a[2]], 's', color=color, markersize=15)
        legend = label+"*"*(passenger_from_id[a[0]].transit_time < 90)
        legend = "c"*(passenger_from_id[a[0]].description =="child") + legend
        plt.text(X[a[1]], Y[a[2]],legend, ha="center", va="center")
        print(f"Passenger ID:{a[0]} - Coordinate: {(a[1], a[2])}")
plt.plot(cm_x,cm_y, "o", color="red")
plt.ylim([-16.5,16.5])
plt.xlim([-3.5,3.5])
# Out:
# Center of Mass: (-0.12, -1.99)
# Passenger ID:0 - Coordinate: (6, 5)
# Passenger ID:1 - Coordinate: (0, 3)
# Passenger ID:2 - Coordinate: (6, 1)
# Passenger ID:3 - Coordinate: (0, 7)
# Passenger ID:4 - Coordinate: (2, 15)
# Passenger ID:5 - Coordinate: (1, 15)
# Passenger ID:6 - Coordinate: (5, 8)
# Passenger ID:7 - Coordinate: (4, 27)
# Passenger ID:8 - Coordinate: (5, 6)
# Passenger ID:9 - Coordinate: (3, 6)
# Passenger ID:10 - Coordinate: (5, 29)
# Passenger ID:11 - Coordinate: (2, 2)
# Passenger ID:12 - Coordinate: (2, 26)
# Passenger ID:13 - Coordinate: (3, 26)
# Passenger ID:14 - Coordinate: (6, 0)
# Passenger ID:15 - Coordinate: (5, 13)
# Passenger ID:16 - Coordinate: (1, 0)
# Passenger ID:17 - Coordinate: (2, 0)
# Passenger ID:18 - Coordinate: (2, 28)
# Passenger ID:19 - Coordinate: (2, 31)
# Passenger ID:20 - Coordinate: (3, 10)
# Passenger ID:21 - Coordinate: (4, 10)
# Passenger ID:22 - Coordinate: (5, 28)
# Passenger ID:23 - Coordinate: (2, 7)
# Passenger ID:24 - Coordinate: (4, 7)
# Passenger ID:25 - Coordinate: (1, 7)
# Passenger ID:26 - Coordinate: (3, 7)
# Passenger ID:27 - Coordinate: (3, 3)
# Passenger ID:28 - Coordinate: (4, 3)
# Passenger ID:29 - Coordinate: (2, 3)
# Passenger ID:30 - Coordinate: (5, 3)
# Passenger ID:31 - Coordinate: (4, 1)
# Passenger ID:32 - Coordinate: (5, 1)
# Passenger ID:33 - Coordinate: (3, 1)
# Passenger ID:34 - Coordinate: (6, 6)
# Passenger ID:35 - Coordinate: (0, 10)
# Passenger ID:36 - Coordinate: (1, 10)
# Passenger ID:37 - Coordinate: (2, 13)
# Passenger ID:38 - Coordinate: (4, 13)
# Passenger ID:39 - Coordinate: (0, 11)
# Passenger ID:40 - Coordinate: (6, 13)
# Passenger ID:41 - Coordinate: (1, 9)
# Passenger ID:42 - Coordinate: (2, 9)
# Passenger ID:43 - Coordinate: (5, 24)
# Passenger ID:44 - Coordinate: (3, 30)
# Passenger ID:45 - Coordinate: (0, 22)
# Passenger ID:46 - Coordinate: (1, 16)
# Passenger ID:47 - Coordinate: (0, 16)
# Passenger ID:48 - Coordinate: (1, 3)
# Passenger ID:49 - Coordinate: (1, 30)
# Passenger ID:50 - Coordinate: (4, 22)
# Passenger ID:51 - Coordinate: (3, 22)
# Passenger ID:52 - Coordinate: (1, 5)
# Passenger ID:53 - Coordinate: (2, 5)
# Passenger ID:54 - Coordinate: (1, 13)
# Passenger ID:55 - Coordinate: (0, 26)
# Passenger ID:56 - Coordinate: (0, 31)
# Passenger ID:57 - Coordinate: (0, 14)
# Passenger ID:58 - Coordinate: (1, 14)
# Passenger ID:59 - Coordinate: (4, 8)
# Passenger ID:60 - Coordinate: (4, 6)
# Passenger ID:61 - Coordinate: (3, 13)
# Passenger ID:62 - Coordinate: (6, 11)
# Passenger ID:63 - Coordinate: (3, 12)
# Passenger ID:64 - Coordinate: (5, 4)
# Passenger ID:65 - Coordinate: (4, 4)
# Passenger ID:66 - Coordinate: (1, 11)
# Passenger ID:67 - Coordinate: (3, 8)
# Passenger ID:68 - Coordinate: (2, 8)
# Passenger ID:69 - Coordinate: (2, 4)
# Passenger ID:70 - Coordinate: (0, 5)
# Passenger ID:71 - Coordinate: (6, 2)
# Passenger ID:72 - Coordinate: (5, 2)
# Passenger ID:73 - Coordinate: (0, 1)
# Passenger ID:74 - Coordinate: (3, 4)
# Passenger ID:75 - Coordinate: (2, 6)
# Passenger ID:76 - Coordinate: (5, 10)
# Passenger ID:77 - Coordinate: (6, 10)
# Passenger ID:78 - Coordinate: (0, 6)
# Passenger ID:79 - Coordinate: (1, 6)
# Passenger ID:80 - Coordinate: (5, 17)
# Passenger ID:81 - Coordinate: (6, 17)
# Passenger ID:82 - Coordinate: (4, 11)
# Passenger ID:83 - Coordinate: (5, 0)
# Passenger ID:84 - Coordinate: (4, 0)
# Passenger ID:85 - Coordinate: (0, 25)
# Passenger ID:86 - Coordinate: (4, 5)
# Passenger ID:87 - Coordinate: (5, 5)
# Passenger ID:88 - Coordinate: (2, 10)
# Passenger ID:89 - Coordinate: (5, 31)
# Passenger ID:90 - Coordinate: (6, 31)
# Passenger ID:91 - Coordinate: (0, 29)
# Passenger ID:92 - Coordinate: (4, 12)
# Passenger ID:93 - Coordinate: (5, 12)
# Passenger ID:94 - Coordinate: (6, 12)
# Passenger ID:95 - Coordinate: (6, 29)
# Passenger ID:96 - Coordinate: (5, 11)
# Passenger ID:97 - Coordinate: (0, 2)
# Passenger ID:98 - Coordinate: (1, 2)
# Passenger ID:99 - Coordinate: (0, 13)
# Passenger ID:100 - Coordinate: (3, 9)
# Passenger ID:101 - Coordinate: (1, 21)
# Passenger ID:102 - Coordinate: (0, 21)
# Passenger ID:103 - Coordinate: (6, 4)
# Passenger ID:104 - Coordinate: (3, 31)
# Passenger ID:105 - Coordinate: (2, 1)
# Passenger ID:106 - Coordinate: (3, 29)
# Passenger ID:107 - Coordinate: (6, 30)
# Passenger ID:108 - Coordinate: (0, 8)
# Passenger ID:109 - Coordinate: (1, 8)
# Passenger ID:110 - Coordinate: (1, 28)
# Passenger ID:111 - Coordinate: (0, 9)
# Passenger ID:112 - Coordinate: (5, 30)
# Passenger ID:113 - Coordinate: (0, 30)
# Passenger ID:114 - Coordinate: (4, 28)
# Passenger ID:115 - Coordinate: (4, 31)
# Passenger ID:116 - Coordinate: (4, 30)
# Passenger ID:117 - Coordinate: (1, 29)
# Passenger ID:118 - Coordinate: (3, 5)
# Passenger ID:119 - Coordinate: (1, 4)
# Passenger ID:120 - Coordinate: (0, 4)
# Passenger ID:121 - Coordinate: (6, 3)
# Passenger ID:122 - Coordinate: (5, 26)
# Passenger ID:123 - Coordinate: (6, 8)
# Passenger ID:124 - Coordinate: (5, 9)
# Passenger ID:125 - Coordinate: (3, 2)
# Passenger ID:126 - Coordinate: (4, 2)
# Passenger ID:127 - Coordinate: (6, 9)
# Passenger ID:128 - Coordinate: (4, 9)
# Passenger ID:129 - Coordinate: (1, 24)
# Passenger ID:130 - Coordinate: (0, 24)
# Passenger ID:131 - Coordinate: (6, 28)
# Passenger ID:132 - Coordinate: (2, 30)
# Passenger ID:133 - Coordinate: (1, 1)
# Passenger ID:134 - Coordinate: (3, 25)
# Passenger ID:135 - Coordinate: (2, 12)
# Passenger ID:136 - Coordinate: (3, 0)
# Passenger ID:137 - Coordinate: (5, 23)
# Passenger ID:138 - Coordinate: (3, 11)
# Passenger ID:139 - Coordinate: (2, 11)
# Passenger ID:140 - Coordinate: (0, 12)
# Passenger ID:141 - Coordinate: (1, 12)
# Passenger ID:142 - Coordinate: (1, 31)
# Passenger ID:143 - Coordinate: (2, 29)
# Passenger ID:144 - Coordinate: (3, 28)
# Passenger ID:145 - Coordinate: (0, 27)
# Passenger ID:146 - Coordinate: (1, 27)
# Passenger ID:147 - Coordinate: (4, 21)
# Passenger ID:148 - Coordinate: (3, 21)
# Passenger ID:149 - Coordinate: (5, 27)
# Passenger ID:150 - Coordinate: (6, 27)
# Passenger ID:151 - Coordinate: (5, 7)
# (-3.5, 3.5)

# %%
print(sum([ val.x for val in j_g_max.values()]))
print(sum([ val.x for val in j_g_min.values()]))

print(sum([ val.x for val in j_g_max.values()]) - sum([ val.x for val in j_g_min.values()]))
print("")

print(sum([ val.x for val in i_g_min.values()]))
print(sum([ val.x for val in i_g_max.values()]))
print(sum([ val.x for val in i_g_max.values()]) - sum([ val.x for val in i_g_min.values()]))
# Out:
# 403.0
# 2835.0
# -2432.0
#
# 528.0
# 115.0
# -413.0

# %%
len(groups)-len(groups_good)
# Out:
# 76

# %%
for g in groups.values():
    print(g)
    print((i_g_max[g.id].x, i_g_min[g.id].x))
# Out:
# G0: [0: (men, 0)]
# (-0.0, 6.0)
# G1: [1: (women, 1)]
# (-0.0, 6.0)
# G2: [2: (men, 2)]
# (-0.0, 6.0)
# G3: [3: (women, 3)]
# (-0.0, 6.0)
# G4: [4: (men, 4), 5: (men, 4)]
# (2.0, 1.0)
# G5: [6: (women, 5)]
# (-0.0, 6.0)
# G6: [7: (women, 6)]
# (-0.0, 6.0)
# G7: [8: (women, 7), 9: (men, 7)]
# (5.0, 3.0)
# G8: [10: (men, 8)]
# (-0.0, 6.0)
# G9: [11: (women, 9)]
# (-0.0, 6.0)
# G10: [12: (women, 10), 13: (men, 10)]
# (3.0, 2.0)
# G11: [14: (men, 11)]
# (-0.0, 6.0)
# G12: [15: (men, 12)]
# (-0.0, 6.0)
# G13: [16: (women, 13), 17: (men, 13)]
# (2.0, 1.0)
# G14: [18: (men, 14)]
# (-0.0, 6.0)
# G15: [19: (men, 15)]
# (-0.0, 6.0)
# G16: [20: (women, 16), 21: (men, 16)]
# (4.0, 3.0)
# G17: [22: (men, 17)]
# (-0.0, 6.0)
# G18: [23: (women, 18), 24: (women, 18), 25: (men, 18), 26: (men, 18)]
# (4.0, 1.0)
# G19: [27: (women, 19), 28: (women, 19), 29: (men, 19), 30: (men, 19)]
# (5.0, 2.0)
# G20: [31: (women, 20), 32: (women, 20), 33: (child, 20)]
# (5.0, 3.0)
# G21: [34: (women, 21)]
# (-0.0, 6.0)
# G22: [35: (women, 22), 36: (men, 22)]
# (1.0, 0.0)
# G23: [37: (women, 23), 38: (men, 23)]
# (4.0, 2.0)
# G24: [39: (men, 24)]
# (-0.0, 6.0)
# G25: [40: (men, 25)]
# (-0.0, 6.0)
# G26: [41: (men, 26), 42: (men, 26)]
# (2.0, 1.0)
# G27: [43: (men, 27)]
# (-0.0, 6.0)
# G28: [44: (women, 28)]
# (-0.0, 6.0)
# G29: [45: (men, 29)]
# (-0.0, 6.0)
# G30: [46: (women, 30), 47: (men, 30)]
# (1.0, -0.0)
# G31: [48: (men, 31)]
# (-0.0, 6.0)
# G32: [49: (men, 32)]
# (-0.0, 6.0)
# G33: [50: (women, 33), 51: (men, 33)]
# (4.0, 3.0)
# G34: [52: (women, 34), 53: (men, 34)]
# (2.0, 1.0)
# G35: [54: (women, 35)]
# (-0.0, 6.0)
# G36: [55: (men, 36)]
# (-0.0, 6.0)
# G37: [56: (men, 37)]
# (-0.0, 6.0)
# G38: [57: (women, 38), 58: (men, 38)]
# (1.0, -0.0)
# G39: [59: (men, 39)]
# (-0.0, 6.0)
# G40: [60: (men, 40)]
# (-0.0, 6.0)
# G41: [61: (men, 41)]
# (-0.0, 6.0)
# G42: [62: (men, 42)]
# (-0.0, 6.0)
# G43: [63: (men, 43)]
# (-0.0, 6.0)
# G44: [64: (women, 44), 65: (men, 44)]
# (5.0, 4.0)
# G45: [66: (men, 45)]
# (-0.0, 6.0)
# G46: [67: (men, 46)]
# (-0.0, 6.0)
# G47: [68: (women, 47)]
# (-0.0, 6.0)
# G48: [69: (men, 48)]
# (-0.0, 6.0)
# G49: [70: (women, 49)]
# (-0.0, 6.0)
# G50: [71: (women, 50), 72: (men, 50)]
# (6.0, 5.0)
# G51: [73: (women, 51)]
# (-0.0, 6.0)
# G52: [74: (women, 52)]
# (-0.0, 6.0)
# G53: [75: (women, 53)]
# (-0.0, 6.0)
# G54: [76: (women, 54), 77: (men, 54)]
# (6.0, 5.0)
# G55: [78: (women, 55), 79: (men, 55)]
# (1.0, -0.0)
# G56: [80: (women, 56), 81: (men, 56)]
# (6.0, 5.0)
# G57: [82: (men, 57)]
# (-0.0, 6.0)
# G58: [83: (women, 58), 84: (men, 58)]
# (5.0, 4.0)
# G59: [85: (women, 59)]
# (-0.0, 6.0)
# G60: [86: (women, 60), 87: (men, 60)]
# (5.0, 4.0)
# G61: [88: (men, 61)]
# (-0.0, 6.0)
# G62: [89: (women, 62), 90: (men, 62)]
# (6.0, 5.0)
# G63: [91: (men, 63)]
# (-0.0, 6.0)
# G64: [92: (women, 64), 93: (women, 64), 94: (men, 64)]
# (6.0, 4.0)
# G65: [95: (women, 65)]
# (-0.0, 6.0)
# G66: [96: (men, 66)]
# (-0.0, 6.0)
# G67: [97: (women, 67), 98: (men, 67)]
# (1.0, -0.0)
# G68: [99: (men, 68)]
# (-0.0, 6.0)
# G69: [100: (women, 69)]
# (-0.0, 6.0)
# G70: [101: (women, 70), 102: (men, 70)]
# (1.0, -0.0)
# G71: [103: (women, 71)]
# (-0.0, 6.0)
# G72: [104: (men, 72)]
# (-0.0, 6.0)
# G73: [105: (men, 73)]
# (-0.0, 6.0)
# G74: [106: (men, 74)]
# (-0.0, 6.0)
# G75: [107: (women, 75)]
# (-0.0, 6.0)
# G76: [108: (women, 76), 109: (men, 76)]
# (1.0, -0.0)
# G77: [110: (men, 77)]
# (-0.0, 6.0)
# G78: [111: (men, 78)]
# (-0.0, 6.0)
# G79: [112: (men, 79)]
# (-0.0, 6.0)
# G80: [113: (men, 80)]
# (-0.0, 6.0)
# G81: [114: (men, 81)]
# (-0.0, 6.0)
# G82: [115: (men, 82)]
# (-0.0, 6.0)
# G83: [116: (men, 83)]
# (-0.0, 6.0)
# G84: [117: (men, 84)]
# (-0.0, 6.0)
# G85: [118: (men, 85)]
# (-0.0, 6.0)
# G86: [119: (women, 86), 120: (men, 86)]
# (1.0, -0.0)
# G87: [121: (women, 87)]
# (-0.0, 6.0)
# G88: [122: (women, 88)]
# (-0.0, 6.0)
# G89: [123: (women, 89)]
# (-0.0, 6.0)
# G90: [124: (men, 90)]
# (-0.0, 6.0)
# G91: [125: (women, 91), 126: (men, 91)]
# (4.0, 3.0)
# G92: [127: (men, 92)]
# (-0.0, 6.0)
# G93: [128: (men, 93)]
# (-0.0, 6.0)
# G94: [129: (women, 94), 130: (men, 94)]
# (1.0, -0.0)
# G95: [131: (women, 95)]
# (-0.0, 6.0)
# G96: [132: (men, 96)]
# (-0.0, 6.0)
# G97: [133: (men, 97)]
# (-0.0, 6.0)
# G98: [134: (men, 98)]
# (-0.0, 6.0)
# G99: [135: (women, 99)]
# (-0.0, 6.0)
# G100: [136: (women, 100)]
# (-0.0, 6.0)
# G101: [137: (men, 101)]
# (-0.0, 6.0)
# G102: [138: (women, 102), 139: (men, 102)]
# (3.0, 2.0)
# G103: [140: (women, 103), 141: (men, 103)]
# (1.0, -0.0)
# G104: [142: (women, 104)]
# (-0.0, 6.0)
# G105: [143: (men, 105)]
# (-0.0, 6.0)
# G106: [144: (women, 106)]
# (-0.0, 6.0)
# G107: [145: (women, 107), 146: (women, 107)]
# (1.0, -0.0)
# G108: [147: (women, 108), 148: (women, 108)]
# (4.0, 3.0)
# G109: [149: (women, 109), 150: (women, 109)]
# (6.0, 5.0)
# G110: [151: (men, 110)]
# (-0.0, 6.0)
